# %% [markdown]
# # Wall-Correction Comparison -- Prop-Off & Prop-On
#
# Compares **raw / uncorrected** coefficients against **wall-corrected (FINAL)** values.
# For prop-on force coefficients, a **BEM thrust-corrected** intermediate layer is also shown.
#
# **Linestyle convention** (same across all plots):
# - `--` dashed  -- raw / uncorrected
# - `:` dotted   -- BEM thrust-corrected (prop-on force coefficients only)
# - `-` solid    -- fully corrected (FINAL)
#
# **Marker convention**:
# - `o` circle   -- raw / uncorrected
# - `^` triangle -- BEM thrust-corrected
# - `s` square   -- fully corrected (FINAL)
#
# **Colour** encodes J value (prop-on combined plots); correction layer is encoded by linestyle/marker.
#
# **Sections**
# 1. Setup & data loading
# 2. Prop-Off (CL, CD, polar, CYaw, CMpitch, delta-alpha shift, multi-beta sweep)
# 3. Prop-On (per-J individual figures + combined J=1.6/2.4 figures; polar overlay; delta increments)

# %% [markdown]
# ## 1  Setup

# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# ── Paths — update to match your directory layout ─────────────────────────────
df_on  = pd.read_csv(r"CORRECTIONS_FINAL\results_propOn_FINAL\propOn_final.csv")
df_on_BEM = pd.read_csv(r"CORRECTIONS_FINAL\results_propOn_FINAL\propOn_final_BEM.csv")
df_off = pd.read_csv(r"CORRECTIONS_FINAL\results_propOff_FINAL\propOff_final.csv")

# ── Global plot settings ──────────────────────────────────────────────────────
J_VALUES_PLOT = []  # J values to include in plots (full alpha sweeps available)
PLOT_PROPOFF_ON_J_PLOTS = True   # overlay prop-off corrected line on per-J and combined figures
FIGSIZE_COMP = (8, 5)
SAVE_RES   = 300
SHOW_TITLE = False
PLOT_DIR   = os.path.join(os.path.dirname(os.path.abspath("__file__")),
                          "correction_comparison_plots")
os.makedirs(PLOT_DIR, exist_ok=True)

mpl.rcParams["axes.labelsize"]  = 12
mpl.rcParams["legend.fontsize"] = 11
mpl.rcParams["xtick.labelsize"] = 10
mpl.rcParams["ytick.labelsize"] = 10
mpl.rcParams["axes.titlesize"]  = 12

# ── Marker convention ─────────────────────────────────────────────────────────
MK_RAW = "o"   # raw / uncorrected
MK_BEM = "^"   # BEM thrust-corrected (prop-on only)
MK_COR = "s"   # fully corrected FINAL
MS     = 5     # marker size

# ── Linestyle convention ──────────────────────────────────────────────────────
LS_RAW = "--"  # raw / uncorrected
LS_BEM = ":"   # BEM thrust-corrected
LS_COR = "-"   # fully corrected FINAL

# %%
# ── Colour palette — uncomment one line to switch all plots ──────────────────
import seaborn as sns

# PALETTE = "colorblind"  # accessible, best for publication (default)
PALETTE = "muted"       # soft, good for reports
# PALETTE = "deep"        # richer / bolder
# PALETTE = "tab10"       # matplotlib default
#PALETTE = "colorblind"

COLORS = sns.color_palette(PALETTE).as_hex()
print(f"Using palette: {PALETTE}")
print(f"Colours: {COLORS}")

# %%
# ── Rounded helper columns ────────────────────────────────────────────────────
for _df in [df_on, df_off]:
    if "V_round"   not in _df.columns: _df["V_round"]   = _df["V"].round()
    if "AoS_round" not in _df.columns: _df["AoS_round"] = _df["AoS"].round()
    if "AoA_round" not in _df.columns: _df["AoA_round"] = _df["AoA"].round(1)

if "J_round" not in df_on.columns:
    df_on["J_round"] = df_on["J"].round(1)

# ── J values used in combined prop-on plots ───────────────────────────────────
J_COMBINED = [1.6, 2.4]   # only these two J values on combined figures

print("df_off shape:", df_off.shape)
print("df_on  shape:", df_on.shape)
print("Prop-off AoS values:", sorted(df_off["AoS_round"].unique()))
print("Prop-off dR  values:", sorted(df_off["dR"].unique()))
print("Prop-on  J   values:", sorted(df_on["J_round"].unique()))
print("Prop-on  dR  values:", sorted(df_on["dR"].unique()))

# %% [markdown]
# ---
# ## 2  Prop-Off -- raw vs corrected
#
# Baseline filter: **V = 40 m/s · AoS = 0° · dR = 0° · dE = 0°**
# Sorted by actual AoA (not rounded) to avoid zigzag from repeated sweeps at the same nominal AoA.
# Raw = `--` dashed · Corrected FINAL = `-` solid

# %% [markdown]
# ### 2.1  $C_L$ vs $\alpha$ -- raw vs corrected

# %%
# -- Prop-off: CL vs AoA
df_base = df_off[
    (df_off["V_round"]   == 40) &
    (df_off["AoS_round"] == 0)  &
    (df_off["dR"]        == 0)  &
    (df_off["dE"]        == 0)
].copy().sort_values("AoA")   # sort by actual AoA to avoid zigzag from repeated sweeps

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
ax.plot(df_base["AoA"],       df_base["CL"],       marker=MK_RAW, markersize=MS,
        linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
ax.plot(df_base["AoA_FINAL"], df_base["CL_FINAL"], marker=MK_COR, markersize=MS,
        linestyle=LS_COR, color=COLORS[0], label="Corrected")

ax.set_xlabel(r"$\alpha$ (°)")
ax.set_ylabel(r"$C_L$")
if SHOW_TITLE:
    ax.set_title(r"$C_L$ vs $\alpha$ -- Prop-off (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propoff_CL_vs_AoA.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 2.2  $C_D$ vs $\alpha$ -- raw vs corrected

# %%
# -- Prop-off: CD vs AoA
df_base = df_off[
    (df_off["V_round"]   == 40) &
    (df_off["AoS_round"] == 0)  &
    (df_off["dR"]        == 0)  &
    (df_off["dE"]        == 0)
].copy().sort_values("AoA")   # sort by actual AoA to avoid zigzag from repeated sweeps

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
ax.plot(df_base["AoA"],       df_base["CD"],       marker=MK_RAW, markersize=MS,
        linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
ax.plot(df_base["AoA_FINAL"], df_base["CD_FINAL"], marker=MK_COR, markersize=MS,
        linestyle=LS_COR, color=COLORS[0], label="Corrected")

ax.set_xlabel(r"$\alpha$ (°)")
ax.set_ylabel(r"$C_D$")
if SHOW_TITLE:
    ax.set_title(r"$C_D$ vs $\alpha$ -- Prop-off (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propoff_CD_vs_AoA.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 2.3  Drag polar ($C_L$ vs $C_D$)

# %%
# -- Prop-off: drag polar (sorted by AoA for clean curve)
df_base = df_off[
    (df_off["V_round"]   == 40) &
    (df_off["AoS_round"] == 0)  &
    (df_off["dR"]        == 0)  &
    (df_off["dE"]        == 0)
].copy().sort_values("AoA")   # sort by actual AoA to avoid zigzag from repeated sweeps

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
ax.plot(df_base["CD"],       df_base["CL"],       marker=MK_RAW, markersize=MS,
        linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
ax.plot(df_base["CD_FINAL"], df_base["CL_FINAL"], marker=MK_COR, markersize=MS,
        linestyle=LS_COR, color=COLORS[0], label="Corrected")

ax.set_xlabel(r"$C_D$")
ax.set_ylabel(r"$C_L$")
if SHOW_TITLE:
    ax.set_title(r"Drag polar -- Prop-off (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propoff_polar.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 2.4  $C_\mathrm{Yaw}$ vs $\alpha$
#
# Duplicate points at the same nominal AoA are real repeated measurement sweeps (e.g. 5 runs at AoA $\approx$ 0°). Sorting by actual AoA rather than rounded AoA eliminates the zigzag between them.

# %%
# -- Prop-off: CYaw vs AoA (sorted by actual AoA to fix zigzag from repeated sweeps)
df_base = df_off[
    (df_off["V_round"]   == 40) &
    (df_off["AoS_round"] == 0)  &
    (df_off["dR"]        == 0)  &
    (df_off["dE"]        == 0)
].copy().sort_values("AoA")   # sort by actual AoA to avoid zigzag from repeated sweeps

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
ax.plot(df_base["AoA"],       df_base["CYaw"],       marker=MK_RAW, markersize=MS,
        linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
ax.plot(df_base["AoA_FINAL"], df_base["CYaw_FINAL"], marker=MK_COR, markersize=MS,
        linestyle=LS_COR, color=COLORS[0], label="Corrected")

ax.set_xlabel(r"$\alpha$ (°)")
ax.set_ylabel(r"$C_\mathrm{Yaw}$")
if SHOW_TITLE:
    ax.set_title(r"$C_\mathrm{Yaw}$ vs $\alpha$ -- Prop-off (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propoff_CYaw_vs_AoA.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 2.5  $C_{M_\mathrm{pitch}}$ vs $\alpha$ -- raw vs corrected

# %%
# -- Prop-off: CMpitch vs AoA
df_base = df_off[
    (df_off["V_round"]   == 40) &
    (df_off["AoS_round"] == 0)  &
    (df_off["dR"]        == 0)  &
    (df_off["dE"]        == 0)
].copy().sort_values("AoA")   # sort by actual AoA to avoid zigzag from repeated sweeps

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
ax.plot(df_base["AoA"],       df_base["CMpitch"],       marker=MK_RAW, markersize=MS,
        linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
ax.plot(df_base["AoA_FINAL"], df_base["CMpitch_FINAL"], marker=MK_COR, markersize=MS,
        linestyle=LS_COR, color=COLORS[0], label="Corrected")

ax.set_xlabel(r"$\alpha$ (°)")
ax.set_ylabel(r"$C_{M_\mathrm{pitch}}$")
if SHOW_TITLE:
    ax.set_title(r"$C_{M_\mathrm{pitch}}$ vs $\alpha$ -- Prop-off (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propoff_CMpitch_vs_AoA.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 2.6  $C_{M_\mathrm{pitch}}$ vs $C_L$

# %%
# -- Prop-off: CMpitch vs CL
df_base = df_off[
    (df_off["V_round"]   == 40) &
    (df_off["AoS_round"] == 0)  &
    (df_off["dR"]        == 0)  &
    (df_off["dE"]        == 0)
].copy().sort_values("AoA")   # sort by actual AoA to avoid zigzag from repeated sweeps

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
ax.plot(df_base["CL"],       df_base["CMpitch"],       marker=MK_RAW, markersize=MS,
        linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
ax.plot(df_base["CL_FINAL"], df_base["CMpitch_FINAL"], marker=MK_COR, markersize=MS,
        linestyle=LS_COR, color=COLORS[0], label="Corrected")

ax.set_xlabel(r"$C_L$")
ax.set_ylabel(r"$C_{M_\mathrm{pitch}}$")
if SHOW_TITLE:
    ax.set_title(r"$C_{M_\mathrm{pitch}}$ vs $C_L$ -- Prop-off (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propoff_CMpitch_vs_CL.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 2.7  $\Delta\alpha$ correction shift vs $\alpha_\mathrm{raw}$
#
# Total AoA shift from all wall corrections (SC + downwash + tail), one line per AoS.

# %%
# -- Prop-off: delta-alpha vs raw AoA -- one line per AoS (V=40, dR=0, dE=0)
aos_values = sorted(df_off[
    (df_off["V_round"] == 40) & (df_off["dR"] == 0) & (df_off["dE"] == 0)
]["AoS_round"].unique())

fig, ax = plt.subplots(figsize=(9, 5))

for idx, aos in enumerate(aos_values):
    grp = df_off[
        (df_off["V_round"]   == 40) &
        (df_off["AoS_round"] == aos) &
        (df_off["dR"]        == 0)   &
        (df_off["dE"]        == 0)
    ].copy().sort_values("AoA")

    x     = grp["AoA"].to_numpy(dtype=float)
    delta = grp["AoA_FINAL"].to_numpy(dtype=float) - x
    fin   = np.isfinite(x) & np.isfinite(delta)
    if fin.sum() < 2:
        continue

    ax.plot(x[fin], delta[fin],
            marker=MK_COR, markersize=MS - 1, linestyle=LS_COR,
            color=COLORS[idx % len(COLORS)],
            label=fr"$\beta$ = {aos}°")

ax.axhline(0, color="gray", linestyle=":", linewidth=1.0)
ax.set_xlabel(r"$\alpha_\mathrm{raw}$ (°)")
ax.set_ylabel(r"$\Delta\alpha = \alpha_\mathrm{FINAL} - \alpha_\mathrm{raw}$ (°)")
if SHOW_TITLE:
    ax.set_title(r"$\Delta\alpha$ correction shift -- Prop-off (V = 40 m/s, $\delta_r$ = 0°)")
ax.legend(ncol=3, fontsize=9)
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propoff_delta_AoA_all_AoS.png"), dpi=150)
plt.show()

# %% [markdown]
# ### 2.8  $C_L$ vs $\alpha$ -- multi-$\beta$ sweep (corrected)
#
# FINAL lift curves for all AoS values tested at V = 40 m/s, dR = 0°.

# %%
# -- Prop-off: CL vs AoA_FINAL -- one line per AoS
fig, ax = plt.subplots(figsize=(9, 6))

for idx, aos in enumerate(aos_values):
    grp = df_off[
        (df_off["V_round"]   == 40) &
        (df_off["AoS_round"] == aos) &
        (df_off["dR"]        == 0)   &
        (df_off["dE"]        == 0)
    ].copy().sort_values("AoA_FINAL")

    x = grp["AoA_FINAL"].to_numpy(dtype=float)
    y = grp["CL_FINAL"].to_numpy(dtype=float)
    fin = np.isfinite(x) & np.isfinite(y)
    if fin.sum() < 2:
        continue

    ax.plot(x[fin], y[fin],
            marker=MK_COR, markersize=MS - 1, linestyle=LS_COR,
            color=COLORS[idx % len(COLORS)],
            label=fr"$\beta$ = {aos}°")

ax.set_xlabel(r"$\alpha_\mathrm{FINAL}$ (°)")
ax.set_ylabel(r"$C_L$")
if SHOW_TITLE:
    ax.set_title(r"$C_L$ vs $\alpha$ (FINAL) -- Prop-off, V = 40 m/s, $\delta_r$ = 0°")
ax.legend(ncol=3, fontsize=9)
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propoff_CL_vs_AoA_FINAL_all_AoS.png"), dpi=150)
plt.show()

# %% [markdown]
# ### 2.9  $C_{M_\mathrm{yaw}}$ vs $\alpha$ -- multi-$\beta$ sweep (corrected)
#
# FINAL lift curves for all AoS values tested at V = 40 m/s, dR = 0°.

# %%
# -- Prop-off: CMyaw vs AoA (sorted by actual AoA to fix zigzag from repeated sweeps)
df_base = df_off[
    (df_off["V_round"]   == 40) &
    (df_off["AoS_round"] == 0)  &
    (df_off["dR"]        == 0)  &
    (df_off["dE"]        == 0)
].copy().sort_values("AoA")

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
ax.plot(df_base["AoA"],       df_base["CMyaw"],       marker=MK_RAW, markersize=MS,
        linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
ax.plot(df_base["AoA_FINAL"], df_base["CMyaw_FINAL"], marker=MK_COR, markersize=MS,
        linestyle=LS_COR, color=COLORS[0], label="Corrected")

ax.set_xlabel(r"$\alpha$ (°)")
ax.set_ylabel(r"$C_{M_\mathrm{yaw}}$")
if SHOW_TITLE:
    ax.set_title(r"$C_{M_\mathrm{yaw}}$ vs $\alpha$ -- Prop-off (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propoff_CMyaw_vs_AoA.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 2.9  $C_{M_\mathrm{yaw}}$ vs $\beta$ -- multi-$\beta$ sweep (corrected)

# %%
# -- Prop-off: CMyaw vs AoS -- one line per AoA (V=40, dR=0, dE=0)
aoa_values = sorted(df_off[
    (df_off["V_round"] == 40) & (df_off["dR"] == 0) & (df_off["dE"] == 0)
]["AoA_round"].unique())

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)

for i, aoa_val in enumerate(aoa_values):
    grp = df_off[
        (df_off["V_round"]   == 40) &
        (df_off["AoA_round"] == aoa_val) &
        (df_off["dR"]        == 0) &
        (df_off["dE"]        == 0)
    ].copy().sort_values("AoS")

    if grp.empty:
        continue

    color = COLORS[i % len(COLORS)]
    ax.plot(grp["AoS"],       grp["CMyaw"],       marker=MK_RAW, markersize=MS,
            linestyle=LS_RAW, color=color)
    ax.plot(grp["AoS_round"], grp["CMyaw_FINAL"], marker=MK_COR, markersize=MS,
            linestyle=LS_COR, color=color, label=fr"$\alpha$ = {aoa_val}°")

ax.set_xlabel(r"$\beta$ (°)")
ax.set_ylabel(r"$C_{M_\mathrm{yaw}}$")
if SHOW_TITLE:
    ax.set_title(r"$C_{M_\mathrm{yaw}}$ vs $\beta$ -- Prop-off (V = 40 m/s, $\delta_r$ = 0°)")
ax.legend(fontsize=9, ncol=2)
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propoff_CMyaw_vs_AoS.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ---
# ## 3  Prop-On -- three correction layers
#
# Baseline filter: **V = 40 m/s · AoS = 0° · dR = 0°**
#
# Each subsection produces:
# - **Individual figures** per J value (all J values; same style as before)
# - **Combined figure** with J = 1.6 and J = 2.4 on the same axes
#   Colour encodes J · Linestyle encodes correction layer (`--` raw, `:` BEM, `-` FINAL)
#
# Force coefficients (CL, CD, CYaw): three series -- raw, BEM, FINAL.
# Moment coefficients (CMpitch, CMyaw): raw vs FINAL only (no BEM intermediate).

# %% [markdown]
# ### 3.1  $C_L$ vs $\alpha$

# %%
# -- Prop-on: CL vs AoA -- individual figure per J (all J values)
j_values_all = sorted(df_on["J_round"].unique())
if J_VALUES_PLOT is not None:
    j_values_all = [j for j in j_values_all if j in J_VALUES_PLOT]

for j_val in j_values_all:
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")
    if grp.empty:
        print(f"No data for J={j_val}"); continue

    x_aoa = grp["AoA"].to_numpy(dtype=float)
    x_fin = grp["AoA_FINAL"].to_numpy(dtype=float)

    fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
    ax.plot(x_aoa, grp["CL"].to_numpy(dtype=float),
            marker=MK_RAW, markersize=MS, linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
    ax.plot(x_aoa, grp["CL_aero_BEM"].to_numpy(dtype=float),
            marker=MK_BEM, markersize=MS, linestyle=LS_BEM, color=COLORS[4], label="Thrust removed")
    ax.plot(x_fin, grp["CL_FINAL"].to_numpy(dtype=float),
            marker=MK_COR, markersize=MS, linestyle=LS_COR, color=COLORS[0], label="Corrected")

    ax.set_xlabel(r"$\alpha$ (°)")
    ax.set_ylabel(r"$C_L$")
    if SHOW_TITLE:
        ax.set_title(fr"$C_L$ vs $\alpha$ -- Prop-on ($J$ = {j_val})")
    if PLOT_PROPOFF_ON_J_PLOTS:
        grp_off = df_off[
            (df_off["V_round"]   == 40) &
            (df_off["AoS_round"] == 0)  &
            (df_off["dR"]        == 0)  &
            (df_off["dE"]        == 0)
        ].copy().sort_values("AoA_FINAL")
        ax.plot(grp_off["AoA_FINAL"], grp_off["CL_FINAL"],   # swap column to match the plot
                marker=MK_COR, markersize=MS - 1, linestyle="-.",
                color="gray", label="Prop-off Corrected")
    ax.legend()
    ax.grid(True)
    plt.tight_layout()
    save_name = f"propon_CL_vs_AoA_J{j_val}.png".replace(".", "p")
    plt.savefig(os.path.join(PLOT_DIR, save_name), dpi=SAVE_RES)
    plt.show()
    print(f"Saved: {save_name}")

# %%
# -- Prop-on: CL vs AoA -- combined figure J=1.6 and J=2.4
# 6 distinct colours: 3 per J, cycled sequentially (colour encodes individual line)
fig, ax = plt.subplots(figsize=FIGSIZE_COMP)

color_idx = 0
for j_val in J_COMBINED:
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")
    if grp.empty:
        print(f"No data for J={j_val}"); continue

    x_aoa = grp["AoA"].to_numpy(dtype=float)
    x_fin = grp["AoA_FINAL"].to_numpy(dtype=float)

    ax.plot(x_aoa, grp["CL"].to_numpy(dtype=float),
            marker=MK_RAW, markersize=MS, linestyle=LS_RAW,
            color=COLORS[color_idx], label=fr"$J$={j_val} Uncorrected")
    ax.plot(x_aoa, grp["CL_aero_BEM"].to_numpy(dtype=float),
            marker=MK_BEM, markersize=MS, linestyle=LS_BEM,
            color=COLORS[color_idx + 1], label=fr"$J$={j_val} Thrust removed")
    ax.plot(x_fin, grp["CL_FINAL"].to_numpy(dtype=float),
            marker=MK_COR, markersize=MS, linestyle=LS_COR,
            color=COLORS[color_idx + 2], label=fr"$J$={j_val} Corrected")
    color_idx += 3

ax.set_xlabel(r"$\alpha$ (°)")
ax.set_ylabel(r"$C_L$")
if SHOW_TITLE:
    ax.set_title(r"$C_L$ vs $\alpha$ -- Prop-on, $J$ = 1.6 & 2.4 (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
if PLOT_PROPOFF_ON_J_PLOTS:
        grp_off = df_off[
            (df_off["V_round"]   == 40) &
            (df_off["AoS_round"] == 0)  &
            (df_off["dR"]        == 0)  &
            (df_off["dE"]        == 0)
        ].copy().sort_values("AoA_FINAL")
        ax.plot(grp_off["AoA_FINAL"], grp_off["CL_FINAL"],   # swap column to match the plot
                marker=MK_COR, markersize=MS - 1, linestyle="-.",
                color="gray", label="Prop-off Corrected")
ax.legend(fontsize=9)
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propon_CL_vs_AoA_J16_J24_combined.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 3.2  $C_D$ vs $\alpha$

# %%
# -- Prop-on: CD vs AoA -- individual figure per J (all J values)
j_values_all = sorted(df_on["J_round"].unique())
if J_VALUES_PLOT is not None:
    j_values_all = [j for j in j_values_all if j in J_VALUES_PLOT]

for j_val in j_values_all:
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")
    if grp.empty:
        print(f"No data for J={j_val}"); continue

    x_aoa = grp["AoA"].to_numpy(dtype=float)
    x_fin = grp["AoA_FINAL"].to_numpy(dtype=float)

    fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
    ax.plot(x_aoa, grp["CD"].to_numpy(dtype=float),
            marker=MK_RAW, markersize=MS, linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
    ax.plot(x_aoa, grp["CD_aero_BEM"].to_numpy(dtype=float),
            marker=MK_BEM, markersize=MS, linestyle=LS_BEM, color=COLORS[4], label="Thrust removed")
    ax.plot(x_fin, grp["CD_FINAL"].to_numpy(dtype=float),
            marker=MK_COR, markersize=MS, linestyle=LS_COR, color=COLORS[0], label="Corrected")

    ax.set_xlabel(r"$\alpha$ (°)")
    ax.set_ylabel(r"$C_D$")
    if SHOW_TITLE:
        ax.set_title(fr"$C_D$ vs $\alpha$ -- Prop-on ($J$ = {j_val})")
    if PLOT_PROPOFF_ON_J_PLOTS:
        grp_off = df_off[
            (df_off["V_round"]   == 40) &
            (df_off["AoS_round"] == 0)  &
            (df_off["dR"]        == 0)  &
            (df_off["dE"]        == 0)
        ].copy().sort_values("AoA_FINAL")
        ax.plot(grp_off["AoA_FINAL"], grp_off["CL_FINAL"],   # swap column to match the plot
                marker=MK_COR, markersize=MS - 1, linestyle="-.",
                color="gray", label="Prop-off Corrected")
    ax.legend()
    ax.grid(True)
    plt.tight_layout()
    save_name = f"propon_CD_vs_AoA_J{j_val}.png".replace(".", "p")
    plt.savefig(os.path.join(PLOT_DIR, save_name), dpi=SAVE_RES)
    plt.show()
    print(f"Saved: {save_name}")

# %%
# -- Prop-on: CD vs AoA -- combined figure J=1.6 and J=2.4
# 6 distinct colours: 3 per J, cycled sequentially (colour encodes individual line)
fig, ax = plt.subplots(figsize=FIGSIZE_COMP)

color_idx = 0
for j_val in J_COMBINED:
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")
    if grp.empty:
        print(f"No data for J={j_val}"); continue

    x_aoa = grp["AoA"].to_numpy(dtype=float)
    x_fin = grp["AoA_FINAL"].to_numpy(dtype=float)

    ax.plot(x_aoa, grp["CD"].to_numpy(dtype=float),
            marker=MK_RAW, markersize=MS, linestyle=LS_RAW,
            color=COLORS[color_idx], label=fr"$J$={j_val} Uncorrected")
    ax.plot(x_aoa, grp["CD_aero_BEM"].to_numpy(dtype=float),
            marker=MK_BEM, markersize=MS, linestyle=LS_BEM,
            color=COLORS[color_idx + 1], label=fr"$J$={j_val} Thrust removed")
    ax.plot(x_fin, grp["CD_FINAL"].to_numpy(dtype=float),
            marker=MK_COR, markersize=MS, linestyle=LS_COR,
            color=COLORS[color_idx + 2], label=fr"$J$={j_val} Corrected")
    color_idx += 3

ax.set_xlabel(r"$\alpha$ (°)")
ax.set_ylabel(r"$C_D$")
if SHOW_TITLE:
    ax.set_title(r"$C_D$ vs $\alpha$ -- Prop-on, $J$ = 1.6 & 2.4 (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
if PLOT_PROPOFF_ON_J_PLOTS:
        grp_off = df_off[
            (df_off["V_round"]   == 40) &
            (df_off["AoS_round"] == 0)  &
            (df_off["dR"]        == 0)  &
            (df_off["dE"]        == 0)
        ].copy().sort_values("AoA_FINAL")
        ax.plot(grp_off["AoA_FINAL"], grp_off["CL_FINAL"],   # swap column to match the plot
                marker=MK_COR, markersize=MS - 1, linestyle="-.",
                color="gray", label="Prop-off Corrected")
ax.legend(fontsize=9)
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propon_CD_vs_AoA_J16_J24_combined.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 3.3  $C_\mathrm{Yaw}$ vs $\alpha$

# %%
# -- Prop-on: CYaw vs AoA -- individual figure per J (all J values)
j_values_all = sorted(df_on["J_round"].unique())
if J_VALUES_PLOT is not None:
    j_values_all = [j for j in j_values_all if j in J_VALUES_PLOT]

for j_val in j_values_all:
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")
    if grp.empty:
        print(f"No data for J={j_val}"); continue

    x_aoa = grp["AoA"].to_numpy(dtype=float)
    x_fin = grp["AoA_FINAL"].to_numpy(dtype=float)

    fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
    ax.plot(x_aoa, grp["CYaw"].to_numpy(dtype=float),
            marker=MK_RAW, markersize=MS, linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
    ax.plot(x_aoa, grp["CYaw_aero_BEM"].to_numpy(dtype=float),
            marker=MK_BEM, markersize=MS, linestyle=LS_BEM, color=COLORS[4], label="Thrust removed")
    ax.plot(x_fin, grp["CYaw_FINAL"].to_numpy(dtype=float),
            marker=MK_COR, markersize=MS, linestyle=LS_COR, color=COLORS[0], label="Corrected")

    ax.set_xlabel(r"$\alpha$ (°)")
    ax.set_ylabel(r"$C_\mathrm{Yaw}$")
    if SHOW_TITLE:
        ax.set_title(fr"$C_\mathrm{{Yaw}}$ vs $\alpha$ -- Prop-on ($J$ = {j_val})")
    if PLOT_PROPOFF_ON_J_PLOTS:
        grp_off = df_off[
            (df_off["V_round"]   == 40) &
            (df_off["AoS_round"] == 0)  &
            (df_off["dR"]        == 0)  &
            (df_off["dE"]        == 0)
        ].copy().sort_values("AoA_FINAL")
        ax.plot(grp_off["AoA_FINAL"], grp_off["CL_FINAL"],   # swap column to match the plot
                marker=MK_COR, markersize=MS - 1, linestyle="-.",
                color="gray", label="Prop-off Corrected")
    ax.legend()
    ax.grid(True)
    plt.tight_layout()
    save_name = f"propon_CYaw_vs_AoA_J{j_val}.png".replace(".", "p")
    plt.savefig(os.path.join(PLOT_DIR, save_name), dpi=SAVE_RES)
    plt.show()
    print(f"Saved: {save_name}")

# %%
# -- Prop-on: CYaw vs AoA -- combined figure J=1.6 and J=2.4
# 6 distinct colours: 3 per J, cycled sequentially (colour encodes individual line)
fig, ax = plt.subplots(figsize=FIGSIZE_COMP)

color_idx = 0
for j_val in J_COMBINED:
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")
    if grp.empty:
        print(f"No data for J={j_val}"); continue

    x_aoa = grp["AoA"].to_numpy(dtype=float)
    x_fin = grp["AoA_FINAL"].to_numpy(dtype=float)

    ax.plot(x_aoa, grp["CYaw"].to_numpy(dtype=float),
            marker=MK_RAW, markersize=MS, linestyle=LS_RAW,
            color=COLORS[color_idx], label=fr"$J$={j_val} Uncorrected")
    ax.plot(x_aoa, grp["CYaw_aero_BEM"].to_numpy(dtype=float),
            marker=MK_BEM, markersize=MS, linestyle=LS_BEM,
            color=COLORS[color_idx + 1], label=fr"$J$={j_val} Thrust removed")
    ax.plot(x_fin, grp["CYaw_FINAL"].to_numpy(dtype=float),
            marker=MK_COR, markersize=MS, linestyle=LS_COR,
            color=COLORS[color_idx + 2], label=fr"$J$={j_val} Corrected")
    color_idx += 3

ax.set_xlabel(r"$\alpha$ (°)")
ax.set_ylabel(r"$C_\mathrm{Yaw}$")
if SHOW_TITLE:
    ax.set_title(r"$C_\mathrm{Yaw}$ vs $\alpha$ -- Prop-on, $J$ = 1.6 & 2.4 (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
if PLOT_PROPOFF_ON_J_PLOTS:
        grp_off = df_off[
            (df_off["V_round"]   == 40) &
            (df_off["AoS_round"] == 0)  &
            (df_off["dR"]        == 0)  &
            (df_off["dE"]        == 0)
        ].copy().sort_values("AoA_FINAL")
        ax.plot(grp_off["AoA_FINAL"], grp_off["CL_FINAL"],   # swap column to match the plot
                marker=MK_COR, markersize=MS - 1, linestyle="-.",
                color="gray", label="Prop-off Corrected")
ax.legend(fontsize=9)
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propon_CYaw_vs_AoA_J16_J24_combined.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 3.4  $C_{M_\mathrm{pitch}}$ vs $\alpha$
#
# No BEM-separated intermediate column for moment coefficients.

# %%
# -- Prop-on: CMpitch vs AoA -- individual figure per J (all J values)
j_values_all = sorted(df_on["J_round"].unique())
if J_VALUES_PLOT is not None:
    j_values_all = [j for j in j_values_all if j in J_VALUES_PLOT]

for j_val in j_values_all:
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")
    if grp.empty:
        print(f"No data for J={j_val}"); continue

    x_aoa = grp["AoA"].to_numpy(dtype=float)
    x_fin = grp["AoA_FINAL"].to_numpy(dtype=float)

    fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
    ax.plot(x_aoa, grp["CMpitch"].to_numpy(dtype=float),
            marker=MK_RAW, markersize=MS, linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
    ax.plot(x_fin, grp["CMpitch_FINAL"].to_numpy(dtype=float),
            marker=MK_COR, markersize=MS, linestyle=LS_COR, color=COLORS[0], label="Corrected")

    ax.set_xlabel(r"$\alpha$ (°)")
    ax.set_ylabel(r"$C_{M_\mathrm{pitch}}$")
    if SHOW_TITLE:
        ax.set_title(fr"$C_{{M_\mathrm{{pitch}}}}$ vs $\alpha$ -- Prop-on ($J$ = {j_val})")
    if PLOT_PROPOFF_ON_J_PLOTS:
        grp_off = df_off[
            (df_off["V_round"]   == 40) &
            (df_off["AoS_round"] == 0)  &
            (df_off["dR"]        == 0)  &
            (df_off["dE"]        == 0)
        ].copy().sort_values("AoA_FINAL")
        ax.plot(grp_off["AoA_FINAL"], grp_off["CL_FINAL"],   # swap column to match the plot
                marker=MK_COR, markersize=MS - 1, linestyle="-.",
                color="gray", label="Prop-off Corrected")
    ax.legend()
    ax.grid(True)
    plt.tight_layout()
    save_name = f"propon_CMpitch_vs_AoA_J{j_val}.png".replace(".", "p")
    plt.savefig(os.path.join(PLOT_DIR, save_name), dpi=SAVE_RES)
    plt.show()
    print(f"Saved: {save_name}")

# %%
# -- Prop-on: CMpitch vs AoA -- combined figure J=1.6 and J=2.4
# 4 distinct colours: 2 per J, cycled sequentially (colour encodes individual line)
fig, ax = plt.subplots(figsize=FIGSIZE_COMP)

color_idx = 0
for j_val in J_COMBINED:
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")
    if grp.empty:
        print(f"No data for J={j_val}"); continue

    ax.plot(grp["AoA"].to_numpy(dtype=float), grp["CMpitch"].to_numpy(dtype=float),
            marker=MK_RAW, markersize=MS, linestyle=LS_RAW,
            color=COLORS[color_idx], label=fr"$J$={j_val} Uncorrected")
    ax.plot(grp["AoA_FINAL"].to_numpy(dtype=float), grp["CMpitch_FINAL"].to_numpy(dtype=float),
            marker=MK_COR, markersize=MS, linestyle=LS_COR,
            color=COLORS[color_idx + 1], label=fr"$J$={j_val} Corrected")
    color_idx += 2

ax.set_xlabel(r"$\alpha$ (°)")
ax.set_ylabel(r"$C_{M_\mathrm{pitch}}$")
if SHOW_TITLE:
    ax.set_title(r"$C_{M_\mathrm{pitch}}$ vs $\alpha$ -- Prop-on, $J$ = 1.6 & 2.4 (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
if PLOT_PROPOFF_ON_J_PLOTS:
        grp_off = df_off[
            (df_off["V_round"]   == 40) &
            (df_off["AoS_round"] == 0)  &
            (df_off["dR"]        == 0)  &
            (df_off["dE"]        == 0)
        ].copy().sort_values("AoA_FINAL")
        ax.plot(grp_off["AoA_FINAL"], grp_off["CL_FINAL"],   # swap column to match the plot
                marker=MK_COR, markersize=MS - 1, linestyle="-.",
                color="gray", label="Prop-off Corrected")
ax.legend(fontsize=9)
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propon_CMpitch_vs_AoA_J16_J24_combined.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 3.5  $C_{M_\mathrm{yaw}}$ vs $\alpha$
#
# No BEM-separated intermediate column for moment coefficients.

# %%
# -- Prop-on: CMyaw vs AoA -- individual figure per J (all J values)
j_values_all = sorted(df_on["J_round"].unique())
if J_VALUES_PLOT is not None:
    j_values_all = [j for j in j_values_all if j in J_VALUES_PLOT]

for j_val in j_values_all:
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")
    if grp.empty:
        print(f"No data for J={j_val}"); continue

    x_aoa = grp["AoA"].to_numpy(dtype=float)
    x_fin = grp["AoA_FINAL"].to_numpy(dtype=float)

    fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
    ax.plot(x_aoa, grp["CMyaw"].to_numpy(dtype=float),
            marker=MK_RAW, markersize=MS, linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
    ax.plot(x_fin, grp["CMyaw_FINAL"].to_numpy(dtype=float),
            marker=MK_COR, markersize=MS, linestyle=LS_COR, color=COLORS[0], label="Corrected")

    ax.set_xlabel(r"$\alpha$ (°)")
    ax.set_ylabel(r"$C_{M_\mathrm{yaw}}$")
    if SHOW_TITLE:
        ax.set_title(fr"$C_{{M_\mathrm{{yaw}}}}$ vs $\alpha$ -- Prop-on ($J$ = {j_val})")
    ax.legend()
    ax.grid(True)
    plt.tight_layout()
    save_name = f"propon_CMyaw_vs_AoA_J{j_val}.png".replace(".", "p")
    plt.savefig(os.path.join(PLOT_DIR, save_name), dpi=SAVE_RES)
    plt.show()
    print(f"Saved: {save_name}")

# %%
# -- Prop-on: CMyaw vs AoA -- combined figure J=1.6 and J=2.4
# 4 distinct colours: 2 per J, cycled sequentially (colour encodes individual line)
fig, ax = plt.subplots(figsize=(8, 5))

color_idx = 0
for j_val in J_COMBINED:
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")
    if grp.empty:
        print(f"No data for J={j_val}"); continue

    ax.plot(grp["AoA"].to_numpy(dtype=float), grp["CMyaw"].to_numpy(dtype=float),
            marker=MK_RAW, markersize=MS, linestyle=LS_RAW,
            color=COLORS[color_idx], label=fr"$J$={j_val} Uncorrected")
    ax.plot(grp["AoA_FINAL"].to_numpy(dtype=float), grp["CMyaw_FINAL"].to_numpy(dtype=float),
            marker=MK_COR, markersize=MS, linestyle=LS_COR,
            color=COLORS[color_idx + 1], label=fr"$J$={j_val} Corrected")
    color_idx += 2

ax.set_xlabel(r"$\alpha$ (°)")
ax.set_ylabel(r"$C_{M_\mathrm{yaw}}$")
if SHOW_TITLE:
    ax.set_title(r"$C_{M_\mathrm{yaw}}$ vs $\alpha$ -- Prop-on, $J$ = 1.6 & 2.4 (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
ax.legend(fontsize=9)
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propon_CMyaw_vs_AoA_J16_J24_combined.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 3.6  Drag polar -- prop-on FINAL vs prop-off FINAL
#
# All J values on one plot; prop-off shown as dashed grey reference.

# %%
# -- Prop-on vs prop-off drag polar (FINAL); all J values
j_values_all = sorted(df_on["J_round"].unique())

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)

for idx, j_val in enumerate(j_values_all):
    grp = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["AoS_round"] == 0)  &
        (df_on["dR"]        == 0)  &
        (df_on["J_round"]   == j_val)
    ].copy().sort_values("AoA_round")

    x = grp["CD_FINAL"].to_numpy(dtype=float)
    y = grp["CL_FINAL"].to_numpy(dtype=float)
    fin = np.isfinite(x) & np.isfinite(y)
    if fin.sum() < 2:
        continue

    ax.plot(x[fin], y[fin],
            marker=MK_COR, markersize=MS, linestyle=LS_COR,
            color=COLORS[idx % len(COLORS)],
            label=fr"Prop-on $J$ = {j_val}")

grp_off = df_off[
    (df_off["V_round"]   == 40) &
    (df_off["AoS_round"] == 0)  &
    (df_off["dR"]        == 0)  &
    (df_off["dE"]        == 0)
].copy().sort_values("AoA_FINAL")

x_off = grp_off["CD_FINAL"].to_numpy(dtype=float)
y_off = grp_off["CL_FINAL"].to_numpy(dtype=float)
fin_off = np.isfinite(x_off) & np.isfinite(y_off)
ax.plot(x_off[fin_off], y_off[fin_off],
        marker=MK_COR, markersize=MS - 1, linestyle=LS_RAW,
        color="gray", label="Prop-off")

ax.set_xlabel(r"$C_D$")
ax.set_ylabel(r"$C_L$")
if SHOW_TITLE:
    ax.set_title(r"Drag polar (FINAL) -- Prop-on vs Prop-off (V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°)")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propon_vs_propoff_polar_FINAL.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 3.7  $C_{M_\mathrm{yaw}}$ vs $\beta$

# %%
# -- Prop-on: CMyaw vs AoS -- J=2.0 only (only J with AoS sweep), AoA = 2.5°
# Moment coefficients: raw vs FINAL only (no BEM intermediate)
grp = df_on[
    (df_on["V_round"]   == 40) &
    (df_on["J_round"]   == 2.0) &
    (df_on["AoA_round"] == 2.5) &
    (df_on["dR"]        == 0)
].copy().sort_values("AoS")

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)
ax.plot(grp["AoS"],       grp["CMyaw"],       marker=MK_RAW, markersize=MS,
        linestyle=LS_RAW, color=COLORS[1], label="Uncorrected")
ax.plot(grp["AoS_round"], grp["CMyaw_FINAL"], marker=MK_COR, markersize=MS,
        linestyle=LS_COR, color=COLORS[0], label="Corrected")

ax.set_xlabel(r"$\beta$ (°)")
ax.set_ylabel(r"$C_{M_\mathrm{yaw}}$")
if SHOW_TITLE:
    ax.set_title(r"$C_{M_\mathrm{yaw}}$ vs $\beta$ -- Prop-on ($J$ = 2.0, $\alpha$ = 2.5°, V = 40 m/s, $\delta_r$ = 0°)")
ax.legend()
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propon_CMyaw_vs_AoS_J2p0_AoA2p5.png"), dpi=SAVE_RES)
plt.show()

# -- Prop-on: CMyaw vs AoS -- J=2.0 sweep + β=0 single points for all other J, with prop-off reference
grp_on = df_on[
    (df_on["V_round"]   == 40) &
    (df_on["J_round"]   == 2.0) &
    (df_on["AoA_round"] == 2.5) &
    (df_on["dR"]        == 0)
].copy().sort_values("AoS")

grp_off = df_off[
    (df_off["V_round"]   == 40) &
    (df_off["AoA_round"] == 2.5) &
    (df_off["dR"]        == 0)   &
    (df_off["dE"]        == 0)
].copy().sort_values("AoS")

fig, ax = plt.subplots(figsize=FIGSIZE_COMP)

# prop-on J=2.0 uncorrected sweep
ax.plot(grp_on["AoS"],       grp_on["CMyaw"],       marker=MK_RAW, markersize=MS,
        linestyle=LS_RAW, color=COLORS[1], label=r"Prop-on Uncorrected ($J$=2.0)")
# prop-on J=2.0 corrected sweep
ax.plot(grp_on["AoS_round"], grp_on["CMyaw_FINAL"], marker=MK_COR, markersize=MS,
        linestyle=LS_COR, color=COLORS[0], label=r"Prop-on Corrected ($J$=2.0)")

# β=0 single points for other J values
other_j = [j for j in sorted(df_on["J_round"].unique()) if j != 2.0]
for i, j_val in enumerate(other_j):
    pt = df_on[
        (df_on["V_round"]   == 40) &
        (df_on["J_round"]   == j_val) &
        (df_on["AoA_round"] == 2.5) &
        (df_on["AoS_round"] == 0) &
        (df_on["dR"]        == 0)
    ]
    if pt.empty:
        continue
    color = COLORS[i + 2]
    ax.scatter(pt["AoS_round"], pt["CMyaw"],       marker=MK_RAW, s=MS**2,
               color=color, zorder=5, label=fr"Prop-on Uncorrected ($J$={j_val}, $\beta$=0°)")
    ax.scatter(pt["AoS_round"], pt["CMyaw_FINAL"], marker=MK_COR, s=MS**2,
               color=color, zorder=5, label=fr"Prop-on Corrected ($J$={j_val}, $\beta$=0°)")

# prop-off corrected reference
ax.plot(grp_off["AoS_round"], grp_off["CMyaw_FINAL"], marker=MK_COR, markersize=MS,
        linestyle=LS_COR, color="gray", label=r"Prop-off Corrected")

ax.set_xlabel(r"$\beta$ (°)")
ax.set_ylabel(r"$C_{M_\mathrm{yaw}}$")
if SHOW_TITLE:
    ax.set_title(r"$C_{M_\mathrm{yaw}}$ vs $\beta$ -- Prop-on vs Prop-off ($\alpha$ = 2.5°, V = 40 m/s, $\delta_r$ = 0°)")
ax.legend(fontsize=9)
ax.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(PLOT_DIR, "propon_CMyaw_vs_AoS_allJ_AoA2p5_vs_propoff.png"), dpi=SAVE_RES)
plt.show()

# %% [markdown]
# ### 3.8  CD comparison

# %%
# ============================================================================
# Comparison plots:
#   - old prop-on FINAL   : df_on
#   - new prop-on FINAL   : df_on_BEM
#   - corresponding prop-off FINAL : df_off
#
# Filtering is done on *_round columns, but plotting uses actual values.
# ============================================================================

# --- helper rounded columns for df_on_BEM if needed
if "V_round" not in df_on_BEM.columns:
    df_on_BEM["V_round"] = df_on_BEM["V"].round()
if "AoS_round" not in df_on_BEM.columns:
    df_on_BEM["AoS_round"] = df_on_BEM["AoS"].round()
if "AoA_round" not in df_on_BEM.columns:
    df_on_BEM["AoA_round"] = df_on_BEM["AoA"].round(1)
if "J_round" not in df_on_BEM.columns and "J" in df_on_BEM.columns:
    df_on_BEM["J_round"] = df_on_BEM["J"].round(1)

# --- use the J values that are actually present in both prop-on datasets
j_values_compare = sorted(
    set(df_on["J_round"].dropna().unique()).intersection(
        set(df_on_BEM["J_round"].dropna().unique())
    )
)
print("J values compared:", j_values_compare)


def _plot_cd_compare_vs_x(
    *,
    x_mode,              # "AoA" or "AoS"
    V_sel,
    dR_sel,
    fixed_AoS_round=None,
    fixed_AoA_round=None,
    save_name="plot.png",
    title_text=""
):
    fig, ax = plt.subplots(figsize=(8, 5))

    # ---- for AoA sweep: only J = 1.6 and 2.4
    if x_mode == "AoA":
        j_values_local = [j for j in j_values_compare if j in [1.6, 2.4]]
    else:
        j_values_local = j_values_compare

    # ---- prop-on old / new (one pair per J)
    color_idx = 0
    for j_val in j_values_local:
        # old prop-on
        grp_old = df_on[
            (df_on["V_round"] == V_sel) &
            (df_on["dR"] == dR_sel) &
            (df_on["J_round"] == j_val)
        ].copy()

        # new prop-on
        grp_new = df_on_BEM[
            (df_on_BEM["V_round"] == V_sel) &
            (df_on_BEM["dR"] == dR_sel) &
            (df_on_BEM["J_round"] == j_val)
        ].copy()

        if fixed_AoS_round is not None:
            grp_old = grp_old[grp_old["AoS_round"] == fixed_AoS_round]
            grp_new = grp_new[grp_new["AoS_round"] == fixed_AoS_round]

        if fixed_AoA_round is not None:
            grp_old = grp_old[grp_old["AoA_round"] == fixed_AoA_round]
            grp_new = grp_new[grp_new["AoA_round"] == fixed_AoA_round]

        sort_col = "AoA_round" if x_mode == "AoA" else "AoS_round"
        grp_old = grp_old.sort_values(sort_col)
        grp_new = grp_new.sort_values(sort_col)

        xcol = "AoA_FINAL" if x_mode == "AoA" else "AoS"
        xlabel = r"$\alpha$ (°)" if x_mode == "AoA" else r"$\beta$ (°)"

        x_old = grp_old[xcol].to_numpy(dtype=float)
        y_old = grp_old["CD_FINAL"].to_numpy(dtype=float)

        x_new = grp_new[xcol].to_numpy(dtype=float)
        y_new = grp_new["CD_FINAL"].to_numpy(dtype=float)

        fin_old = np.isfinite(x_old) & np.isfinite(y_old)
        fin_new = np.isfinite(x_new) & np.isfinite(y_new)

        color_this = COLORS[color_idx % len(COLORS)]

        if fin_old.sum() >= 2:
            ax.plot(
                x_old[fin_old], y_old[fin_old],
                marker="s", markersize=MS, linestyle="-",
                color=color_this,
                label=fr"$J$ = {j_val} Corrected EXP"
            )

        if fin_new.sum() >= 2:
            ax.plot(
                x_new[fin_new], y_new[fin_new],
                marker="^", markersize=MS, linestyle="--",
                color=color_this,
                label=fr"$J$ = {j_val} Corrected BEM"
            )

        color_idx += 1

    # ---- corresponding prop-off
    grp_off = df_off[
        (df_off["V_round"] == V_sel) &
        (df_off["dR"] == dR_sel) &
        (df_off["dE"] == 0)
    ].copy()

    if fixed_AoS_round is not None:
        grp_off = grp_off[grp_off["AoS_round"] == fixed_AoS_round]

    if fixed_AoA_round is not None:
        grp_off = grp_off[grp_off["AoA_round"] == fixed_AoA_round]

    # Hardcoded deduplication for the last plot only (V=40, AoA=2.5, AoS sweep):
    # at AoS=-10 the lower duplicate is spurious -> drop it (keep max)
    # at AoS=+10 the higher duplicate is spurious -> drop it (keep min)
    if x_mode == "AoS" and V_sel == 40 and fixed_AoA_round == 2.5:
        mask_neg10 = grp_off["AoS_round"] == -10.0
        mask_pos10 = grp_off["AoS_round"] == 10.0
        idx_drop_neg10 = grp_off[mask_neg10]["CD_FINAL"].idxmin()
        idx_drop_pos10 = grp_off[mask_pos10]["CD_FINAL"].idxmax()
        grp_off = grp_off.drop(index=[idx_drop_neg10, idx_drop_pos10])

    sort_col = "AoA_round" if x_mode == "AoA" else "AoS_round"
    grp_off = grp_off.sort_values(sort_col)

    xcol_off = "AoA_FINAL" if x_mode == "AoA" else "AoS"
    x_off = grp_off[xcol_off].to_numpy(dtype=float)
    y_off = grp_off["CD_FINAL"].to_numpy(dtype=float)
    fin_off = np.isfinite(x_off) & np.isfinite(y_off)

    if fin_off.sum() >= 2:
        ax.plot(
            x_off[fin_off], y_off[fin_off],
            marker="o", markersize=MS - 1, linestyle="-.",
            color="gray", label="Prop-off Corrected"
        )

    ax.set_xlabel(xlabel)
    ax.set_ylabel(r"$C_D$")
    if SHOW_TITLE:
        ax.set_title(title_text)
    ax.legend(fontsize=9, ncol=2)
    ax.grid(True)
    plt.tight_layout()
    plt.savefig(os.path.join(PLOT_DIR, save_name), dpi=150)
    plt.show()


# ============================================================================
# 1) CD vs AoA
#    V = 40 m/s, dR = 0, AoS = 0
#    only J = 1.6 and 2.4
# ============================================================================

_plot_cd_compare_vs_x(
    x_mode="AoA",
    V_sel=40,
    dR_sel=0,
    fixed_AoS_round=0,
    fixed_AoA_round=None,
    save_name="CD_compare_old_vs_EXP_vs_propoff_V40_dR0_AoS0_vs_AoA.png",
    title_text=r"$C_D$ vs $\alpha$ -- V = 40 m/s, $\beta$ = 0°, $\delta_r$ = 0°"
)


# ============================================================================
# 2) CD vs AoS
#    V = 20 m/s, dR = 0, AoA = 2.5°
# ============================================================================

_plot_cd_compare_vs_x(
    x_mode="AoS",
    V_sel=20,
    dR_sel=0,
    fixed_AoS_round=None,
    fixed_AoA_round=2.5,
    save_name="CD_compare_old_vs_EXP_vs_propoff_V20_dR0_AoA2p5_vs_AoS.png",
    title_text=r"$C_D$ vs $\beta$ -- V = 20 m/s, $\alpha$ = 2.5°, $\delta_r$ = 0°"
)


# ============================================================================
# 3) CD vs AoS
#    V = 40 m/s, dR = 0, AoA = 2.5°
# ============================================================================

_plot_cd_compare_vs_x(
    x_mode="AoS",
    V_sel=40,
    dR_sel=0,
    fixed_AoS_round=None,
    fixed_AoA_round=2.5,
    save_name="CD_compare_old_vs_EXP_vs_propoff_V40_dR0_AoA2p5_vs_AoS.png",
    title_text=r"$C_D$ vs $\beta$ -- V = 40 m/s, $\alpha$ = 2.5°, $\delta_r$ = 0°"
)
